# %% [markdown]
# <a href="https://colab.research.google.com/github/MeerMusabih/FlyRank-AI-Internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MeerMusabih/FlyRank-AI-Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
LANE 2:  Refresh / Content Opportunity Scoring
It focuses on a practical search intelligence problem:
identifying which pages should be reviewed first for possible refresh, improvement, protection, or monitoring.
This lane matches the goal of using data and ML to prioritize content decisions instead of relying only on manual rules.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
It improves the process to identify which content pages should be reviewed first for refresh, improvement, protection, or monitoring.
SEO specialists, content strategists, and marketing teams use the ranked recommendations to prioritize their work.
A wrong recommendation can waste time and resources on low-impact pages while missing pages with higher potential for improving visibility or engagement.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
elif os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")  # move from notebooks/ to the repo root

print("Working dir:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "starter CSV not found — are you at the repo root?"
print("Starter data found. You're ready.")

import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total pages:", len(df))

visible_pages = (df["impressions_90d"] > 0).sum()
print("Pages with impressions in last 90 days:", visible_pages)

declining_pages = (df["trend_direction"] == "down").sum()
print("Pages showing declining trend:", declining_pages)

print("Average 90-day impressions per page:", round(df["impressions_90d"].mean(), 2))
# Out:
# Working dir: /content/flyrank-ml-internship-starter
# Starter data found. You're ready.
# Total pages: 30000
# Pages with impressions in last 90 days: 30000
# Pages showing declining trend: 16262
# Average 90-day impressions per page: 5200.37

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
Claims:
  It can identify patterns and signals associated with pages that may need review.
  It can provide a ranked, data-driven list to support content prioritization decisions.
  It can show which observable factors are related to content performance and opportunity.
Cannot Claim:
  It cannot prove that a content refresh will cause traffic or ranking improvements.
  It cannot predict Google's algorithm or search ranking decisions.
  It cannot guarantee that a recommended page will recover after changes.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
